# %% [markdown]
# <a href="https://colab.research.google.com/github/jeetgandhi112/House-Price-Prediction-Project/blob/main/House_Price_Prediction_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
from google.colab import files
upload = files.upload()
data = pd.read_csv("house_data1.csv")
data.head()
# Out:
#      <input type="file" id="files-c0614293-d4e5-4ac9-a96d-c268664d57b8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0614293-d4e5-4ac9-a96d-c268664d57b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data.describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  6.960000e+02  6.960000e+02  696.000000  696.000000    696.000000
# mean   4.496248e+09  5.258361e+05    3.362069    2.077586   2131.120690
# std    2.922628e+09  3.499337e+05    0.870589    0.739614   1066.366262
# min    1.150089e+07  8.000000e+04    1.000000    0.750000    430.000000
# 25%    1.874900e+09  3.050000e+05    3.000000    1.750000   1420.000000
# 50%    3.830630e+09  4.355000e+05    3.000000    2.250000   1970.000000
# 75%    7.328750e+09  6.390250e+05    4.000000    2.500000   2570.000000
# max    9.828703e+09  3.080000e+06    7.000000    5.000000  15603.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     696.000000  696.000000  696.000000  696.000000  696.000000
# mean    16362.143678    1.454023    0.010057    0.241379    3.462644
# std     33331.518678    0.498961    0.099853    0.791546    0.692227
# ...

# %%
data.count()
# Out:
# id               696
# price            696
# bedrooms         696
# bathrooms        696
# sqft_living      696
# sqft_lot         696
# floors           696
# waterfront       696
# view             696
# condition        696
# grade            696
# sqft_above       696
# sqft_basement    696
# yr_built         696
# yr_renovated     696
# zipcode          696
# lat              696
# long             696
# sqft_living15    696
# sqft_lot15       696
# dtype: int64

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x=data.lat.values, y=data.long.values, size=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price,data.sqft_living)
plt.title("Price vs Square Feet")
# Out:
# Text(0.5, 1.0, 'Price vs Square Feet')

# %%
plt.scatter(data.price,data.long)
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
plt.scatter(data.price,data.lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter((data['sqft_living']+data['sqft_basement']),data['price'])

# %%
plt.scatter(data.waterfront,data.price)
plt.title("Waterfront vs Price ( 0= no waterfront)")
# Out:
# Text(0.5, 1.0, 'Waterfront vs Price ( 0= no waterfront)')

# %%
train1 = data.drop(['id', 'price'],axis=1)
train1.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
data.floors.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.scatter(data.floors,data.price)

# %%
plt.scatter(data.condition,data.price)

# %%
plt.scatter(data.zipcode,data.price)
plt.title("Which is the pricey location by zipcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode?')

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
labels = data['price']
train1 = data.drop(['id', 'price'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r1=reg.score(x_test,y_test)
r1
# Out:
# 0.700840625091373

# %%
r2=(r1*100)
print(r2,'%')
# Out:
# 70.0840625091373 %

# %%
np.random.seed(42)
from sklearn.ensemble import RandomForestRegressor
reg1 = RandomForestRegressor()
X1 = data.drop(['price'], axis=1)
y1 = data['price']
from sklearn.model_selection import train_test_split
X1_train , X1_test , y1_train , y1_test = train_test_split(X1 ,y1 , test_size = 0.20, random_state =2)
reg1.fit(X1_train , y1_train)
reg1.score(X1_test, y1_test)
# Out:
# 0.7715827492357232

# %%
np.random.seed(42)
from sklearn import svm
reg2 = svm.SVR()
X2 = data.drop(['price'], axis=1)
y2 = data['price']
from sklearn.model_selection import train_test_split
X2_train , X2_test , y2_train , y2_test = train_test_split(X2 ,y2 , test_size = 0.20, random_state =2)
reg2.fit(X1_train , y1_train)
reg2.score(X1_test, y1_test)
# Out:
# -0.07724871422522428
